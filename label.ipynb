# %%
import os
import pandas as pd

# %%
df = pd.read_csv('labels.csv',header=None)
df.rename(columns={0 : 'index', 1 : 'genres'}, inplace= True)
df
# Out:
#         index   genres
# 0           2  Hip-Hop
# 1           3  Hip-Hop
# 2           5  Hip-Hop
# 3          10      Pop
# 4         134  Hip-Hop
# ...       ...      ...
# 49593  155315     Rock
# 49594  155316     Rock
# 49595  155317     Rock
# 49596  155318     Rock
# 49597  155319     Rock
#
# [49598 rows x 2 columns]

# %%
df['genres'].unique()
# Out:
# array(['Hip-Hop', 'Pop', 'Rock', 'Experimental', 'Folk', 'Jazz',
#        'Electronic', 'Spoken', 'International', 'Soul-RnB', 'Blues',
#        'Country', 'Classical', 'Old-Time / Historic', 'Instrumental',
#        'Easy Listening'], dtype=object)

# %%
folder = os.listdir('Data/fma_small/')
folder = [x for x in folder if x.isdigit()]
folder
# Out:
# ['099',
#  '139',
#  '073',
#  '069',
#  '030',
#  '107',
#  '061',
#  '039',
#  '037',
#  '048',
#  '101',
#  '067',
#  '031',
#  '064',
#  '125',
#  '123',
#  '000',
#  '043',
#  '052',
#  '049',
#  '095',
#  '080',
#  '077',
#  '027',
#  '097',
#  '092',
#  '009',
#  '132',
#  '111',
#  '068',
#  '011',
#  '138',
#  '083',
#  '154',
#  '045',
#  '093',
#  '057',
#  '004',
#  '059',
#  '007',
#  '135',
#  '012',
#  '146',
#  '149',
#  '113',
#  '018',
#  '076',
#  '071',
#  '070',
#  '005',
#  '025',
#  '102',
#  '032',
#  '053',
#  '020',
#  '089',
#  '084',
#  '019',
#  '042',
#  '126',
#  '141',
#  '035',
#  '137',
#  '024',
#  '108',
#  '120',
#  '124',
#  '074',
#  '085',
#  '115',
#  '015',
#  '062',
#  '151',
#  '104',
#  '046',
#  '013',
#  '026',
#  '122',
#  '140',
#  '022',
#  '094',
#  '075',
#  '091',
#  '155',
#  '014',
#  '023',
#  '118',
#  '066',
#  '010',
#  '051',
#  '114',
#  '081',
#  '147',
#  '153',
#  '016',
#  '001',
#  '088',
#  '056',
#  '041',
#  '050',
#  '036',
#  '112',
#  '021',
#  '131',
#  '072',
#  '116',
#  '136',
#  '130',
#  '152',
#  '029',
#  '106',
#  '127',
#  '055',
#  '109',
#  '117',
#  '033',
#  '100',
#  '150',
#  '003',
#  '143',
#  '105',
#  '134',
#  '008',
#  '148',
#  '038',
#  '079',
#  '040',
#  '028',
#  '065',
#  '058',
#  '110',
#  '128',
#  '142',
#  '090',
#  '133',
#  '096',
#  '121',
#  '098',
#  '006',
#  '034',
#  '103',
#  '082',
#  '087',
#  '017',
#  '054',
#  '063',
#  '119',
#  '144',
#  '060',
#  '145',
#  '086',
#  '002',
#  '044',
#  '047',
#  '129',
#  '078']

# %%
for i in folder:
    subf = os.listdir('Data/fma_small/' + i)
